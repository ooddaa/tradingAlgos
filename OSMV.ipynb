# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# thanks dude

# %%
for i in range(1):            
    for chunk in pd.read_csv("D:\\code\\OSMV.csv", chunksize=1024):
        print(chunk)
# Out:
#      ticker  stkPx   expirDate      yte  strike  cVolu  cOi  pVolu  pOi  \
# 0         A  38.41  2015-11-20  0.00822    22.5      0    0      1    7
# 1         A  38.41  2015-11-20  0.00822    25.0      0    0     10   30
# 2         A  38.41  2015-11-20  0.00822    27.5      0    0      3    3
# 3         A  38.41  2015-11-20  0.00822    30.0      6    6      2  192
# 4         A  38.41  2015-11-20  0.00822    32.5      2   29      2  640
# ...     ...    ...         ...      ...     ...    ...  ...    ...  ...
# 1019    AAN  23.62  2016-05-20  0.50685    30.0      1    1      0    0
# 1020    AAN  23.62  2016-05-20  0.50685    31.0      0    0      1    1
# 1021    AAN  23.62  2016-05-20  0.50685    32.0      0    0      0    0
# 1022    AAN  23.62  2016-05-20  0.50685    33.0      0    0      0    0
# 1023    AAN  23.62  2016-05-20  0.50685    34.0      0    0      1    1
#
#       cBidPx  ...     theta      vega       rho       phi  driftlessTheta  \
# ...
