# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# took my office laptop like 20 seconds to compute, shouldve %time
plt.plot([1,2,3,4])

# %%
# %time plt.plot(np.random.randn(100))
# Out:
# Wall time: 187 ms
